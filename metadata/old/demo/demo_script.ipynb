# %%
import pandas as pd
import os
import ast
import re

# %%
list_name = os.listdir('./')

# %%
list_name
# Out:
# ['DEMO_codebook.csv',
#  'DEMO_dictionary_mapping.csv',
#  'demo_script.ipynb',
#  'nhanes_codebook_resultados_com_tabelas.csv',
#  'P_DEMO_DEMO.csv',
#  'tabelas_completas.csv']

# %%
nhanes_codebook = pd.read_csv('nhanes_codebook_resultados_com_tabelas.csv')

# %%
df_sem_duplicatas = nhanes_codebook.drop_duplicates()
df_sem_duplicatas
# Out:
#      Tabela  Variavel Variable_Name                            SAS_Label  \
# 0      DEMO      SEQN          SEQN           Respondent sequence number
# 1      DEMO  SDDSRVYR      SDDSRVYR                  Data Release Number
# 2      DEMO  RIDSTATR      RIDSTATR         Interview/Examination Status
# 3      DEMO  RIDEXMON      RIDEXMON                Six month time period
# 4      DEMO  RIAGENDR      RIAGENDR                               Gender
# ..      ...       ...           ...                                  ...
# 593  DEMO_L  WTINT2YR      WTINT2YR  Full sample 2-year interview weight
# 594  DEMO_L  WTMEC2YR      WTMEC2YR   Full sample 2-year MEC exam weight
# 595  DEMO_L  SDMVSTRA      SDMVSTRA       Masked variance pseudo-stratum
# 596  DEMO_L   SDMVPSU       SDMVPSU           Masked variance pseudo-PSU
# 597  DEMO_L  INDFMPIR      INDFMPIR    Ratio of family income to poverty
#
#                                           English_Text  \
# 0                          Respondent sequence number.
# 1                                 Data Release Number.
# 2    Interview and Examination Status of the Sample...
# 3    Six month time period when the examination was...
# 4                          Gender of the sample person
# ..                                                 ...
# 593               Full sample 2 year interview weight.
# 594                Full sample 2 year MEC exam weight.
# 595  Masked variance unit pseudo-stratum variable f...
# 596  Masked variance unit pseudo-PSU variable for v...
# 597                  Ratio of family income to poverty
#
#                                          Target  \
# 0    Both males and females 0 YEARS - 150 YEARS
# 1    Both males and females 0 YEARS - 150 YEARS
# 2    Both males and females 0 YEARS - 150 YEARS
# 3    Both males and females 0 YEARS - 150 YEARS
# 4    Both males and females 0 YEARS - 150 YEARS
# ..                                          ...
# 593  Both males and females 0 YEARS - 150 YEARS
# 594  Both males and females 0 YEARS - 150 YEARS
# 595  Both males and females 0 YEARS - 150 YEARS
# 596  Both males and females 0 YEARS - 150 YEARS
# 597  Both males and females 0 YEARS - 150 YEARS
#
#                                         Tabela_Valores
# 0                                                  NaN
# 1    Code.or.Value=["1", "."]; Value.Description=["...
# 2    Code.or.Value=["1", "2", "."]; Value.Descripti...
# 3    Code.or.Value=["1", "2", "."]; Value.Descripti...
# 4    Code.or.Value=["1", "2", "."]; Value.Descripti...
# ..                                                 ...
# 593  Code.or.Value=["4584.463196 to 170968.343177",...
# 594  Code.or.Value=["4581.595095 to 227108.296958",...
# 595  Code.or.Value=["173 to 187", "."]; Value.Descr...
# 596  Code.or.Value=["1 to 2", "."]; Value.Descripti...
# 597  Code.or.Value=["0 to 4.99", "5", "."]; Value.D...
#
# [598 rows x 7 columns]

# %%
df_sem_duplicatas[df_sem_duplicatas['Variavel']=='INDFMPIR']
# Out:
#      Tabela  Variavel Variable_Name                          SAS_Label  \
# 22     DEMO  INDFMPIR      INDFMPIR                         Family PIR
# 166  DEMO_B  INDFMPIR      INDFMPIR                         Family PIR
# 203  DEMO_C  INDFMPIR      INDFMPIR                         Family PIR
# 246  DEMO_D  INDFMPIR      INDFMPIR                         Family PIR
# 289  DEMO_E  INDFMPIR      INDFMPIR  Ratio of family income to poverty
# 332  DEMO_F  INDFMPIR      INDFMPIR  Ratio of family income to poverty
# 390  DEMO_G  INDFMPIR      INDFMPIR  Ratio of family income to poverty
# 448  DEMO_H  INDFMPIR      INDFMPIR  Ratio of family income to poverty
# 495  DEMO_I  INDFMPIR      INDFMPIR  Ratio of family income to poverty
# 541  DEMO_J  INDFMPIR      INDFMPIR  Ratio of family income to poverty
# 550  P_DEMO  INDFMPIR      INDFMPIR  Ratio of family income to poverty
# 597  DEMO_L  INDFMPIR      INDFMPIR  Ratio of family income to poverty
#
#                                           English_Text  \
# 22   Poverty income ratio (PIR) - a ratio of family...
# 166  Poverty income ratio (PIR) - a ratio of family...
# 203  Poverty income ratio (PIR) - a ratio of family...
# 246  Poverty income ratio (PIR) - a ratio of family...
# 289      A ratio of family income to poverty threshold
# 332      A ratio of family income to poverty threshold
# 390    A ratio of family income to poverty guidelines.
# 448    A ratio of family income to poverty guidelines.
# 495    A ratio of family income to poverty guidelines.
# 541    A ratio of family income to poverty guidelines.
# 550    A ratio of family income to poverty guidelines.
# 597                  Ratio of family income to poverty
#
#                                          Target  \
# 22   Both males and females 0 YEARS - 150 YEARS
# 166  Both males and females 0 YEARS - 150 YEARS
# 203  Both males and females 0 YEARS - 150 YEARS
# 246  Both males and females 0 YEARS - 150 YEARS
# 289  Both males and females 0 YEARS - 150 YEARS
# 332  Both males and females 0 YEARS - 150 YEARS
# 390  Both males and females 0 YEARS - 150 YEARS
# 448  Both males and females 0 YEARS - 150 YEARS
# 495  Both males and females 0 YEARS - 150 YEARS
# 541  Both males and females 0 YEARS - 150 YEARS
# 550  Both males and females 0 YEARS - 150 YEARS
# 597  Both males and females 0 YEARS - 150 YEARS
#
#                                         Tabela_Valores
# 22   Code.or.Value=["0 to 4.99", "5", "."]; Value.D...
# 166  Code.or.Value=["0 to 4.99", "5", "."]; Value.D...
# 203  Code.or.Value=["0 to 4.99", "5", "."]; Value.D...
# 246  Code.or.Value=["0 to 4.99", "5", "."]; Value.D...
# 289  Code.or.Value=["0 to 4.99", "5", "."]; Value.D...
# 332  Code.or.Value=["0 to 4.99", "5", "."]; Value.D...
# 390  Code.or.Value=["0 to 4.99", "5", "."]; Value.D...
# 448  Code.or.Value=["0 to 4.99", "5", "."]; Value.D...
# 495  Code.or.Value=["0 to 4.99", "5", "."]; Value.D...
# 541  Code.or.Value=["0 to 4.98", "5", "."]; Value.D...
# 550  Code.or.Value=["0 to 4.98", "5", "."]; Value.D...
# 597  Code.or.Value=["0 to 4.99", "5", "."]; Value.D...

# %%
codebook_select_col = df_sem_duplicatas[['Tabela','Variable_Name', 'SAS_Label', 'Tabela_Valores','English_Text', 'Target']]

# %%
codebook_select_col
# Out:
#      Tabela Variable_Name                            SAS_Label  \
# 0      DEMO          SEQN           Respondent sequence number
# 1      DEMO      SDDSRVYR                  Data Release Number
# 2      DEMO      RIDSTATR         Interview/Examination Status
# 3      DEMO      RIDEXMON                Six month time period
# 4      DEMO      RIAGENDR                               Gender
# ..      ...           ...                                  ...
# 593  DEMO_L      WTINT2YR  Full sample 2-year interview weight
# 594  DEMO_L      WTMEC2YR   Full sample 2-year MEC exam weight
# 595  DEMO_L      SDMVSTRA       Masked variance pseudo-stratum
# 596  DEMO_L       SDMVPSU           Masked variance pseudo-PSU
# 597  DEMO_L      INDFMPIR    Ratio of family income to poverty
#
#                                         Tabela_Valores  \
# 0                                                  NaN
# 1    Code.or.Value=["1", "."]; Value.Description=["...
# 2    Code.or.Value=["1", "2", "."]; Value.Descripti...
# 3    Code.or.Value=["1", "2", "."]; Value.Descripti...
# 4    Code.or.Value=["1", "2", "."]; Value.Descripti...
# ..                                                 ...
# 593  Code.or.Value=["4584.463196 to 170968.343177",...
# 594  Code.or.Value=["4581.595095 to 227108.296958",...
# 595  Code.or.Value=["173 to 187", "."]; Value.Descr...
# 596  Code.or.Value=["1 to 2", "."]; Value.Descripti...
# 597  Code.or.Value=["0 to 4.99", "5", "."]; Value.D...
#
#                                           English_Text  \
# 0                          Respondent sequence number.
# 1                                 Data Release Number.
# 2    Interview and Examination Status of the Sample...
# 3    Six month time period when the examination was...
# 4                          Gender of the sample person
# ..                                                 ...
# 593               Full sample 2 year interview weight.
# 594                Full sample 2 year MEC exam weight.
# 595  Masked variance unit pseudo-stratum variable f...
# 596  Masked variance unit pseudo-PSU variable for v...
# 597                  Ratio of family income to poverty
#
#                                          Target
# 0    Both males and females 0 YEARS - 150 YEARS
# 1    Both males and females 0 YEARS - 150 YEARS
# 2    Both males and females 0 YEARS - 150 YEARS
# 3    Both males and females 0 YEARS - 150 YEARS
# 4    Both males and females 0 YEARS - 150 YEARS
# ..                                          ...
# 593  Both males and females 0 YEARS - 150 YEARS
# 594  Both males and females 0 YEARS - 150 YEARS
# 595  Both males and females 0 YEARS - 150 YEARS
# 596  Both males and females 0 YEARS - 150 YEARS
# 597  Both males and females 0 YEARS - 150 YEARS
#
# [598 rows x 6 columns]

# %%
codebook_select_col[codebook_select_col['Variable_Name']=='WTINT2YR']
# Out:
#      Tabela Variable_Name                            SAS_Label  \
# 31     DEMO      WTINT2YR  Full Sample 2 Year Interview Weight
# 175  DEMO_B      WTINT2YR  Full Sample 2 Year Interview Weight
# 221  DEMO_C      WTINT2YR  Full Sample 2 Year Interview Weight
# 264  DEMO_D      WTINT2YR  Full Sample 2 Year Interview Weight
# 307  DEMO_E      WTINT2YR  Full Sample 2 Year Interview Weight
# 350  DEMO_F      WTINT2YR  Full Sample 2 Year Interview Weight
# 384  DEMO_G      WTINT2YR  Full sample 2 year interview weight
# 442  DEMO_H      WTINT2YR  Full sample 2 year interview weight
# 489  DEMO_I      WTINT2YR  Full sample 2 year interview weight
# 535  DEMO_J      WTINT2YR  Full sample 2 year interview weight
# 593  DEMO_L      WTINT2YR  Full sample 2-year interview weight
#
#                                         Tabela_Valores  \
# 31   Code.or.Value=["974.66525161 to 236864.13597",...
# 175  Code.or.Value=["1492.093618 to 201188.12151", ...
# 221  Code.or.Value=["1498.994197 to 156319.65778", ...
# 264  Code.or.Value=["1224.968032 to 152162.42158", ...
# 307  Code.or.Value=["2359.373828 to 186295.50665", ...
# 350  Code.or.Value=["3279.931789 to 153810.25883", ...
# 384  Code.or.Value=["3320.8855 to 220233.3152", "."...
# 442  Code.or.Value=["3697.772098 to 167884.54371", ...
# 489  Code.or.Value=["3293.928267 to 233755.84185", ...
# 535  Code.or.Value=["2571.0687123 to 433085.00526",...
# 593  Code.or.Value=["4584.463196 to 170968.343177",...
#
#                              English_Text  \
# 31            Interviewed Sample Persons.
# 175           Interviewed Sample Persons.
# 221           Interviewed Sample Persons.
# 264           Interviewed Sample Persons.
# 307           Interviewed Sample Persons.
# 350           Interviewed Sample Persons.
# 384             Interviewed participants.
# 442  Full sample 2 year interview weight.
# 489  Full sample 2 year interview weight.
# 535  Full sample 2 year interview weight.
# 593  Full sample 2 year interview weight.
#
#                                          Target
# 31   Both males and females 0 YEARS - 150 YEARS
# 175  Both males and females 0 YEARS - 150 YEARS
# 221  Both males and females 0 YEARS - 150 YEARS
# 264  Both males and females 0 YEARS - 150 YEARS
# 307  Both males and females 0 YEARS - 150 YEARS
# 350  Both males and females 0 YEARS - 150 YEARS
# 384  Both males and females 0 YEARS - 150 YEARS
# 442  Both males and females 0 YEARS - 150 YEARS
# 489  Both males and females 0 YEARS - 150 YEARS
# 535  Both males and females 0 YEARS - 150 YEARS
# 593  Both males and females 0 YEARS - 150 YEARS

# %%
list_Variable_Name = codebook_select_col['Variable_Name'].unique()
df_codebook_final = pd.DataFrame()

for variable in list_Variable_Name:
    df_now = codebook_select_col[codebook_select_col['Variable_Name']==variable]
    list_english = list(df_now['English_Text'].unique())
    list_Target = list(df_now['Target'].unique())
    df_now['English_Text'] = str(list_english)
    df_now['Target'] = str(list_Target)

    df_codebook_final = pd.concat([df_codebook_final, df_now])
# Out:
# C:\Users\l-oen\AppData\Local\Temp\ipykernel_21732\571734007.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_now['English_Text'] = str(list_english)
# C:\Users\l-oen\AppData\Local\Temp\ipykernel_21732\571734007.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_now['Target'] = str(list_Target)

# %%
df_codebook_final
# Out:
#      Tabela Variable_Name                     SAS_Label  \
# 0      DEMO          SEQN    Respondent sequence number
# 144  DEMO_B          SEQN    Respondent sequence number
# 181  DEMO_C          SEQN    Respondent sequence number
# 225  DEMO_D          SEQN    Respondent sequence number
# 268  DEMO_E          SEQN    Respondent sequence number
# ..      ...           ...                           ...
# 585  DEMO_L      DMDMARTZ                Marital status
# 546  P_DEMO      DMDYRUSZ          Length of time in US
# 569  P_DEMO      WTINTPRP  Full sample interview weight
# 570  P_DEMO      WTMECPRP   Full sample MEC exam weight
# 583  DEMO_L      DMDYRUSR          Length of time in US
#
#                                         Tabela_Valores  \
# 0                                                  NaN
# 144                                                NaN
# 181                                                NaN
# 225                                                NaN
# 268                                                NaN
# ..                                                 ...
# 585  Code.or.Value=["1", "2", "3", "77", "99", "."]...
# 546  Code.or.Value=["1", "2", "3", "4", "77", "99",...
# 569  Code.or.Value=["1017.784203 to 338363.60019", ...
# 570  Code.or.Value=["0 to 367555.74298", "."]; Valu...
# 583  Code.or.Value=["1", "2", "3", "4", "5", "6", "...
#
#                                           English_Text  \
# 0                      ['Respondent sequence number.']
# 144                    ['Respondent sequence number.']
# 181                    ['Respondent sequence number.']
# 225                    ['Respondent sequence number.']
# 268                    ['Respondent sequence number.']
# ..                                                 ...
# 585                                 ['Marital status']
# 546  ['Length of time the participant has been in t...
# 569                   ['Full sample interview weight']
# 570                    ['Full sample MEC exam weight']
# 583  ['Length of time the participant has been in t...
#
#                                               Target
# 0     ['Both males and females 0 YEARS - 150 YEARS']
# 144   ['Both males and females 0 YEARS - 150 YEARS']
# 181   ['Both males and females 0 YEARS - 150 YEARS']
# 225   ['Both males and females 0 YEARS - 150 YEARS']
# 268   ['Both males and females 0 YEARS - 150 YEARS']
# ..                                               ...
# 585  ['Both males and females 20 YEARS - 150 YEARS']
# 546   ['Both males and females 0 YEARS - 150 YEARS']
# 569   ['Both males and females 0 YEARS - 150 YEARS']
# 570   ['Both males and females 0 YEARS - 150 YEARS']
# 583   ['Both males and females 0 YEARS - 150 YEARS']
#
# [598 rows x 6 columns]

# %%
def process_string_to_dict(string):
    string = string.split('; Count')[0]
    # Substituir os `;` por vírgulas e remover espaços extras
    formatted_string = re.sub(r";", ",", string)
    formatted_string = re.sub(r"=", ":", formatted_string)
    # Adicionar chaves externas para transformá-la em um dicionário
    formatted_string = "{" + formatted_string + "}"
    # Substituir chaves como "Code.or.Value" por "Code" e "Value.Description" por "Description"
    formatted_string = re.sub(r"Code\.or\.Value", '"Code"', formatted_string)
    formatted_string = re.sub(r"Value\.Description", '"Description"', formatted_string)

    return eval(formatted_string)

# %%
rows = []
for _, row in df_codebook_final.iterrows():
    # Ignorar linhas onde Tabela_Valores é NaN
    if pd.isna(row['Tabela_Valores']):
        rows.append({
                    "Column": row["Variable_Name"],
                    "Code": None,
                    "Label": None,
                    "English_Text": row["English_Text"],
                    "Target": row["Target"]
                })
        continue
    
    # Extrair os dados de Code e Value.Description
    valores = row['Tabela_Valores']
    
    try:
        # Usando ast.literal_eval para transformar a string em dicionário
        parsed_values = process_string_to_dict(valores)
        codes = parsed_values["Code"]
        codes = [str(item).title() for item in codes]
        descriptions = parsed_values["Description"]
        descriptions = [str(item).title() for item in descriptions]
        # Criar uma nova linha para cada combinação de Code e Description
        for code, description in zip(codes, descriptions):
            rows.append({
                "Column": row["Variable_Name"],
                "Code": code,
                "Label": description,
                "English_Text": row["English_Text"],
                "Target": row["Target"]
            })
    except Exception as e:
        print(f"Erro ao processar a linha: {row['Tabela_Valores']}")
        print(e)

# Criar um novo DataFrame com os dados processados
df_expanded = pd.DataFrame(rows)
df_expanded['Class'] = None
df_expanded['Other For'] = None

# %%
df_expanded
# Out:
#         Column  Code             Label  \
# 0         SEQN  None              None
# 1         SEQN  None              None
# 2         SEQN  None              None
# 3         SEQN  None              None
# 4         SEQN  None              None
# ...        ...   ...               ...
# 2687  DMDYRUSR     5    15 To 19 Years
# 2688  DMDYRUSR     6  20 Years Or More
# 2689  DMDYRUSR    77           Refused
# 2690  DMDYRUSR    99        Don'T Know
# 2691  DMDYRUSR     .           Missing
#
#                                            English_Text  \
# 0                       ['Respondent sequence number.']
# 1                       ['Respondent sequence number.']
# 2                       ['Respondent sequence number.']
# 3                       ['Respondent sequence number.']
# 4                       ['Respondent sequence number.']
# ...                                                 ...
# 2687  ['Length of time the participant has been in t...
# 2688  ['Length of time the participant has been in t...
# 2689  ['Length of time the participant has been in t...
# 2690  ['Length of time the participant has been in t...
# 2691  ['Length of time the participant has been in t...
#
#                                               Target Class Other For
# 0     ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 1     ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 2     ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 3     ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 4     ['Both males and females 0 YEARS - 150 YEARS']  None      None
# ...                                              ...   ...       ...
# 2687  ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 2688  ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 2689  ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 2690  ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 2691  ['Both males and females 0 YEARS - 150 YEARS']  None      None
#
# [2692 rows x 7 columns]

# %%
df_expanded.drop_duplicates(inplace=True)

# %%
df_expanded
# Out:
#         Column  Code                            Label  \
# 0         SEQN  None                             None
# 12    SDDSRVYR     1  Nhanes 1999-2000 Public Release
# 13    SDDSRVYR     .                          Missing
# 14    SDDSRVYR     2  Nhanes 2001-2002 Public Release
# 16    SDDSRVYR     3  Nhanes 2003-2004 Public Release
# ...        ...   ...                              ...
# 2687  DMDYRUSR     5                   15 To 19 Years
# 2688  DMDYRUSR     6                 20 Years Or More
# 2689  DMDYRUSR    77                          Refused
# 2690  DMDYRUSR    99                       Don'T Know
# 2691  DMDYRUSR     .                          Missing
#
#                                            English_Text  \
# 0                       ['Respondent sequence number.']
# 12       ['Data Release Number.', 'Data release cycle']
# 13       ['Data Release Number.', 'Data release cycle']
# 14       ['Data Release Number.', 'Data release cycle']
# 16       ['Data Release Number.', 'Data release cycle']
# ...                                                 ...
# 2687  ['Length of time the participant has been in t...
# 2688  ['Length of time the participant has been in t...
# 2689  ['Length of time the participant has been in t...
# 2690  ['Length of time the participant has been in t...
# 2691  ['Length of time the participant has been in t...
#
#                                               Target Class Other For
# 0     ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 12    ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 13    ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 14    ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 16    ['Both males and females 0 YEARS - 150 YEARS']  None      None
# ...                                              ...   ...       ...
# 2687  ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 2688  ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 2689  ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 2690  ['Both males and females 0 YEARS - 150 YEARS']  None      None
# 2691  ['Both males and females 0 YEARS - 150 YEARS']  None      None
#
# [689 rows x 7 columns]

# %%
df_expanded.to_csv('DEMO_codebook.csv', sep=',', encoding='utf-8')

# %%
dictionary_mapping = codebook_select_col[['Variable_Name']]

# %%
dictionary_mapping = dictionary_mapping.drop_duplicates(subset='Variable_Name', keep='first')

# %%
dictionary_mapping['Attribute'] = None
dictionary_mapping['attributeOf'] = None
dictionary_mapping['Unit'] = None
dictionary_mapping['Time'] = None
dictionary_mapping['Entity'] = None
dictionary_mapping['Role'] = None
dictionary_mapping['Relation'] = None
dictionary_mapping['inRelationTo'] = None
dictionary_mapping['wasDerivedFrom'] = None
dictionary_mapping['wasGeneratedBy'] = None

# %%
dictionary_mapping.reset_index(inplace=True, drop=True)

# %%
dictionary_mapping
# Out:
#     Variable_Name Attribute attributeOf  Unit  Time Entity  Role Relation  \
# 0            SEQN      None        None  None  None   None  None     None
# 1        SDDSRVYR      None        None  None  None   None  None     None
# 2        RIDSTATR      None        None  None  None   None  None     None
# 3        RIDEXMON      None        None  None  None   None  None     None
# 4        RIAGENDR      None        None  None  None   None  None     None
# ..            ...       ...         ...   ...   ...    ...   ...      ...
# 174      DMDMARTZ      None        None  None  None   None  None     None
# 175      DMDYRUSZ      None        None  None  None   None  None     None
# 176      WTINTPRP      None        None  None  None   None  None     None
# 177      WTMECPRP      None        None  None  None   None  None     None
# 178      DMDYRUSR      None        None  None  None   None  None     None
#
#     inRelationTo wasDerivedFrom wasGeneratedBy
# 0           None           None           None
# 1           None           None           None
# 2           None           None           None
# 3           None           None           None
# 4           None           None           None
# ..           ...            ...            ...
# 174         None           None           None
# 175         None           None           None
# 176         None           None           None
# 177         None           None           None
# 178         None           None           None
#
# [179 rows x 11 columns]

# %%
dictionary_mapping.rename(columns={"Variable_Name": "Column"}, inplace=True)

# %%
dictionary_mapping.to_csv('DEMO_dictionary_mapping.csv', sep=',', encoding='utf-8')
